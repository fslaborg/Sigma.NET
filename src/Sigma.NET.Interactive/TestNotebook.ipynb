# %% [markdown]
# To reproduce the package, run `./Repack.ps1` in powershell. It will clean your cache in `~/.nuget/packages` and pack the library to `sigmaNET/pkg` folder, which you should specify below (absolute paths only) in `#i` line.
#
# The version of the package is always `0.0.0-dev`.

# %%
// be advised, that you always should set absolute paths for local nuget packages - change this to reflect your own setup
#r "nuget: Giraffe.ViewEngine"
#i "nuget: C:/Users/schne/source/repos/fslaborg/Sigma.NET/pkg"
#r "nuget: Sigma.NET, 0.0.0-dev"
#r "nuget: Sigma.NET.Interactive, 0.0.0-dev"
#r "nuget: Graphoscope, 0.4.0"
# Out:
# <div><div><strong>Restore sources</strong><ul><li><span> C:/Users/schne/source/repos/fslaborg/Sigma.NET/pkg</span></li></ul></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Giraffe.ViewEngine, 1.4.0</span></li><li><span>Graphoscope, 0.4.0</span></li><li><span>Sigma.NET, 0.0.0-dev</span></li><li><span>Sigma.NET.Interactive, 0.0.0-dev</span></li></ul></div></div>
# Loading extensions from `C:\Users\schne\.nuget\packages\sigma.net.interactive\0.0.0-dev\lib\net6.0\Sigma.NET.Interactive.dll`

# %% [markdown]
# ###Task1: hallo

# %%
open Sigma.NET
open Sigma.NET.Interactive

let rnd = new Random()
let colors = [|"#F2FFE9";"#A6CF98";"#557C55";"#FA7070"|]

Graph.empty()
|> Graph.withNodes [
        Node.Init(key=string "n1", X=1, Y=2, Size=rnd.Next(1, 18), Color=colors.[rnd.Next(0, 4)])
        Node.Init(key=string "n2", X=3, Y=4, Size=rnd.Next(1, 18), Color=colors.[rnd.Next(0, 4)])
        Node.Init(key=string "n3", X=5, Y=8, Size=rnd.Next(1, 18), Color=colors.[rnd.Next(0, 4)])
    ]
|> Graph.withEdges [
        Edge.Init("n1", "n2")
        Edge.Init("n2", "n3")
    ]
|> Graph.withCircularLayout()
|> Graph.withSize(CssLength.Percent(100), CssLength.PX(300))
# Out:
# <div id="graph"><div id="e14a933e4db" style="width: 100%; height: 300px">&nbsp<!-- Sigma.NET graph will be drawn inside this DIV --></div><script type="text/javascript">
#
#     require([
#         'https://cdnjs.cloudflare.com/ajax/libs/graphology/0.25.4/graphology.umd.min.js',
#         'https://cdnjs.cloudflare.com/ajax/libs/sigma.js/2.4.0/sigma.min.js',
#         'https://cdn.jsdelivr.net/npm/graphology-library@0.8.0/dist/graphology-library.min.js',
#     ], (graphology,_,graphologyLibrary)=>{
#             const container = document.getElementById("e14a933e4db");
#             const graph = new graphology.Graph();
#             graph.import({"nodes":[{"key":"n1","attributes":{"x":1,"y":2,"size":13,"color":"#F2FFE9"}},{"key":"n2","attributes":{"x":3,"y":4,"size":1,"color":"#557C55"}},{"key":"n3","attributes":{"x":5,"y":8,"size":11,"color":"#FA7070"}}],"edges":[{"source":"n1","target":"n2"},{"source":"n2","target":"n3"}]});
#             graphologyLibrary.layout.circular.assign(graph, {});
#             const renderer = new Sigma(graph, container,{});
#
#         });
#     </script></div>

# %%
open Graphoscope
open Graphoscope.RandomModels

let colors = [|"#F2FFE9";"#A6CF98";"#557C55";"#FA7070"|]

let N = 1000
let p = 0.005
let rnd = new Random()
let random_number = rnd.Next(1, 51)

let myBollobasRiordan = RandomModels.BollobasRiordan.initDirectedFGraph  N 0.5 0.1 0.4 0.6 0.4 FGraph.empty

Graph.empty()
|> Graph.withNodes[
    for node in myBollobasRiordan do
        yield (Node.Init(key=string node.Key, Size=rnd.Next(1, 18), Label=string node.Key, Color=colors.[rnd.Next(0, 4) ]))

]
|> Graph.withEdges [
    for node in myBollobasRiordan do
        let pred,t,_ = node.Value
        for kv in pred do
            yield (Edge.Init(source=string kv.Key, target=string t,Size=rnd.Next(1, 3)) )

]

|> Graph.withForceAtlas2(Iterations=100,Settings=FA2Settings.Init(AdjustSizes=true,Gravity=5),GetEdgeWeight="size")
|> Graph.withRenderer(Render.Settings.Init(LabelColor="#FA7070"))
// |> Graph.withNoverlap(50)
//|> Graph.withCircularLayout()
# Out:
# <div id="graph"><div id="e0d95a46e7b" style="width: 100%; height: 900px">&nbsp<!-- SigmaNET graph will be drawn inside this DIV --></div><script type="text/javascript">
#
#     require([
#         'https://cdnjs.cloudflare.com/ajax/libs/graphology/0.25.4/graphology.umd.min.js',
#         'https://cdnjs.cloudflare.com/ajax/libs/sigma.js/2.4.0/sigma.min.js',
#         'https://cdn.jsdelivr.net/npm/graphology-library@0.8.0/dist/graphology-library.min.js',
#     ], (graphology,_,graphologyLibrary)=>{
#             const container = document.getElementById("e0d95a46e7b");
#             const graph = new graphology.Graph();
#             graph.import({"nodes":[{"key":"0","attributes":{"size":17,"label":"0","color":"#FA7070"}},{"key":"1","attributes":{"size":9,"label":"1","color":"#F2FFE9"}},{"key":"2","attributes":{"size":13,"label":"2","color":"#557C55"}},{"key":"3","attributes":{"size":8,"label":"3","color":"#A6CF98"}},{"key":"4","attributes":{"size":12,"label":"4","color":"#F2FFE9"}},{"key":"5","attributes":{"size":1,"label":"5","color":"#FA7070"}},{"key":"6","attributes":{"size":12,"label":"6","color":"#F2FFE9"}},{"key":"7","attributes":{"size":6,"label":"7","color":"#A6CF98"}},{"key":"8","attributes":{"size":9,"label":"8","color":"#557C55"}},{"key":"9","attributes":{"size":9,"label":"9","color":"#A6CF98"}},{"key":"10","attributes":{"size":13,"label":"10","color":"#FA7070"}},{"key":"11","attributes":{"size":16,"label":"11","color":"#557C55"}},{"key":"12","attributes":{"size":6,"label":"12","color":"#FA7070"}},{"key":"13","attributes":{"size":5,"label":"13","color":"#FA7070"}},{"key":"14","attributes":{"size":6,"label":"14","color":"#F2FFE9"}},{"key":"15","attributes":{"size":2,"label":"15","color":"#A6CF98"}},{"key":"16","attributes":{"size":10,"label":"16","color":"